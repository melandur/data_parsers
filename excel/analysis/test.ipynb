# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# pandas show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Load the Excel file using pandas
df = pd.read_excel('/home/melandur/Data/Myocarditis/new/5_merged/layer_analysis_imputed.xlsx')

# %%
matrix = df.corr()
matrix = matrix.unstack()
matrix = matrix[abs(matrix) <= 0.01]

print(matrix)
print(matrix)
# Out:
# global_longit_strain            hxhtn                             0.007819
#                                 baseline_vt_before_cmr           -0.007551
#                                 baseline_meds_entresto           -0.009812
#                                 Diagn_modality_none              -0.002356
#                                 Diagn_modality_catheter           0.002439
#                                 Diagn_modality_cct                0.004839
# endo_longit_strain              hxhtn                             0.004069
#                                 baseline_vt_before_cmr           -0.000938
#                                 Diagn_modality_none              -0.001493
# epi_longit_strain               baseline_vt_before_cmr           -0.005563
#                                 baseline_meds_entresto           -0.008326
#                                 Diagn_modality_none               0.001082
#                                 Diagn_modality_catheter           0.008540
#                                 Diagn_modality_cct                0.003469
# global_circumf_strain           baseline_hypertensive_cm         -0.009319
#                                 baselie_prior_myocarditis        -0.006023
#                                 baseline_vt_before_cmr           -0.009906
#                                 baseline_meds_entresto            0.008223
#                                 baseline_meds_other_ad           -0.003578
#                                 Diagn_type_base_or_fu             0.003891
#                                 Diagn_modality_cct                0.004305
# endo_circumf_strain             hxhtn                             0.000586
#                                 hxchol                            0.002245
#                                 baselie_prior_myocarditis         0.009985
#                                 baseline_meds_aldosteron_ag      -0.003718
#                                 baseline_meds_other_ad            0.003233
#                                 Diagn_type_base_or_fu             0.008182
#                                 Diagn_sympt_fatigue               0.002619
#                                 Diagn_setting_acute_subacute     -0.007317
#                                 Diagn_modality_cct                0.002956
# epi_circumf_strain              fhxcad___3                        0.004764
#                                 baselie_prior_myocarditis        -0.001448
#                                 baseline_meds_aldosteron_ag      -0.007309
#                                 baseline_meds_entresto            0.004054
#                                 baseline_meds_other_ad           -0.003897
#                                 Diagn_type_base_or_fu             0.000332
#                                 Diagn_modality_cct               -0.007628
# global_radial_strain            baseline_hypertensive_cm          0.002824
#                                 baseline_stroke_tia               0.007872
#                                 baselie_prior_myocarditis         0.006707
#                                 baseline_vt_before_cmr            0.002871
#                                 baseline_meds_other_ad           -0.003484
#                                 baseline_meds_nitrates           -0.009899
#                                 Diagn_setting_acute_subacute      0.007386
# endo_radial_strain              age                              -0.009336
#                                 hxhtn                             0.000248
#                                 hxchol                           -0.002844
#                                 baseline_stroke_tia               0.009629
#                                 baseline_meds_aldosteron_ag       0.001404
#                                 baseline_meds_nitrates           -0.003903
#                                 Diagn_setting_acute_subacute     -0.007311
# epi_radial_strain               fhxcad___3                       -0.006630
#                                 baselie_prior_myocarditis         0.002163
#                                 baseline_meds_aldosteron_ag       0.004294
#                                 baseline_meds_entresto           -0.009741
#                                 baseline_meds_other_ad           -0.002333
#                                 Diagn_type_base_or_fu            -0.007011
#                                 Diagn_modality_cct                0.002533
# subject                         Diagn_sympt_fatigue              -0.001227
# sex_0_male_1_female             dm_ja_nein                        0.005656
#                                 baseline_af                      -0.007994
#                                 baseline_stroke_tia              -0.007994
#                                 baseline_meds_oac                -0.009564
#                                 Diagn_sympt_exercise_intol       -0.005890
#                                 Diagn_sympt_edema                 0.000972
#                                 Diagn_sympt_typ_ap               -0.003634
#                                 Diagn_sympt_atyp_chestpain       -0.008193
#                                 Diagn_sympt_any_chestpain        -0.009519
#                                 Diagn_modality_none              -0.007994
#                                 Diagn_modality_emb               -0.000832
# age                             endo_radial_strain               -0.009336
#                                 baseline_other                   -0.007897
#                                 baseline_meds_aldosteron_ag      -0.007243
#                                 baseline_meds_entresto           -0.000266
#                                 baseline_meds_immunosuppresant    0.004559
#                                 Diagn_sympt_card_arrest           0.004186
#                                 Diagn_sympt_fatigue               0.008806
#                                 Diagn_modality_catheter           0.001980
#                                 Diagn_modality_cct               -0.003668
# bmi                             baseline_active_cancer            0.008427
#                                 baseline_meds_oac                -0.001177
#                                 baseline_meds_entresto           -0.001216
#                                 baseline_meds_sglt2               0.008427
#                                 Diagn_type_base_or_fu            -0.008404
#                                 Diagn_sympt_none                 -0.009625
#                                 Diagn_sympt_orthopnoea            0.007954
#                                 Diagn_sympt_edema                 0.000039
#                                 Diagn_sympt_any_chestpain        -0.008919
#                                 Diagn_modality_none              -0.006438
# mace                            fhxcad___1                        0.004421
#                                 baseline_asthma                   0.003502
#                                 baseline_dcm                     -0.002713
#                                 baseline_meds_calcium_ag          0.000806
#                                 Diagn_sympt_noc_dyspnoea          0.003502
# hxhtn                           global_longit_strain              0.007819
#                                 endo_longit_strain                0.004069
#                                 endo_circumf_strain               0.000586
#                                 endo_radial_strain                0.000248
#                                 baseline_af                       0.009126
#                                 baseline_stroke_tia               0.009126
#                                 baseline_autoimmune_disease       0.003448
#                                 baselie_prior_myocarditis        -0.003357
#                                 baseline_dcm                      0.003448
#                                 baseline_chf_hosp_before_cmr      0.003448
#                                 baseline_vt_before_cmr           -0.003357
#                                 baseline_meds_betablocker        -0.007590
#                                 Diagn_sympt_jointpain             0.009126
#                                 Diagn_modality_none               0.009126
# hxdm                            baseline_no_comorbidity          -0.003832
#                                 Diagn_sympt_none                  0.005460
#                                 Diagn_sympt_card_arrest           0.009301
#                                 Diagn_setting_acute_subacute     -0.008902
#                                 Diagn_modality_echo              -0.004347
#                                 Diagn_modality_catheter          -0.001517
# dm_ja_nein                      sex_0_male_1_female               0.005656
#                                 fhxcad___3                        0.003507
#                                 baseline_meds_betablocker         0.004995
#                                 Diagn_sympt_syncope              -0.007414
#                                 Diagn_sympt_arrhythmia           -0.000847
# hxchol                          endo_circumf_strain               0.002245
#                                 endo_radial_strain               -0.002844
#                                 fhxcad___1                       -0.009786
#                                 fhxcad___2                       -0.006991
#                                 baselie_prior_myocarditis        -0.006991
#                                 Diagn_sympt_exercise_intol        0.008765
#                                 Diagn_sympt_typ_ap               -0.008699
#                                 Diagn_nyha                       -0.007716
#                                 Diagn_modality_echo               0.006229
# fhxcad___1                      mace                              0.004421
#                                 hxchol                           -0.009786
#                                 baseline_icd                     -0.009340
#                                 baseline_pfo_asd_occlusion       -0.009340
#                                 baseline_active_cancer           -0.009340
#                                 baseline_meds_none                0.003971
#                                 baseline_meds_aldosteron_ag      -0.009340
#                                 baseline_meds_diuretic           -0.005037
#                                 baseline_meds_betablocker        -0.007070
#                                 baseline_meds_entresto           -0.009340
#                                 baseline_meds_metformin           0.003971
#                                 baseline_meds_sglt2              -0.009340
#                                 baseline_meds_other_ad           -0.009340
#                                 baseline_meds_steroid            -0.009340
#                                 Diagn_type_base_or_fu            -0.009340
#                                 Diagn_sympt_exercise_intol        0.001555
#                                 Diagn_sympt_typ_ap               -0.006213
#                                 Diagn_sympt_card_shock           -0.009340
# fhxcad___2                      hxchol                           -0.006991
#                                 baseline_icd                     -0.002738
#                                 baseline_pfo_asd_occlusion       -0.002738
#                                 baseline_pah                     -0.003875
#                                 baseline_hypertensive_cm         -0.003875
#                                 baseline_asthma                  -0.006729
#                                 baseline_active_cancer           -0.002738
#                                 baseline_stroke_tia              -0.004749
#                                 baseline_depression              -0.005487
#                                 baseline_autoimmune_disease      -0.007274
#                                 baselie_prior_myocarditis        -0.005487
#                                 baseline_other                   -0.006139
#                                 baseline_vt_before_cmr           -0.005487
#                                 baseline_meds_ass                -0.001557
#                                 baseline_meds_aldosteron_ag      -0.002738
#                                 baseline_meds_entresto           -0.002738
#                                 baseline_meds_statin              0.008601
#                                 baseline_meds_sglt2              -0.002738
#                                 baseline_meds_other_ad           -0.002738
#                                 baseline_meds_steroid            -0.002738
#                                 baseline_meds_immunosuppresant   -0.003875
#                                 baseline_meds_nitrates           -0.009556
#                                 Diagn_type_base_or_fu            -0.002738
#                                 Diagn_sympt_noc_dyspnoea         -0.006729
#                                 Diagn_sympt_edema                -0.006139
#                                 Diagn_sympt_jointpain            -0.004749
#                                 Diagn_sympt_card_shock           -0.002738
#                                 Diagn_modality_none              -0.004749
#                                 Diagn_modality_cct               -0.003875
#                                 Diagn_modality_stress_ecg        -0.003875
# fhxcad___3                      epi_circumf_strain                0.004764
#                                 epi_radial_strain                -0.006630
#                                 dm_ja_nein                        0.003507
#                                 baseline_icd                     -0.004347
#                                 baseline_pfo_asd_occlusion       -0.004347
#                                 baseline_af                      -0.007539
#                                 baseline_pah                     -0.006152
#                                 baseline_hypertensive_cm         -0.006152
#                                 basline_osas                     -0.006152
#                                 baseline_copd                    -0.006152
#                                 baseline_active_cancer           -0.004347
#                                 baseline_depression              -0.008712
#                                 baseline_other                   -0.009747
#                                 baseline_meds_aldosteron_ag      -0.004347
#                                 baseline_meds_ace                -0.005191
#                                 baseline_meds_entresto           -0.004347
#                                 baseline_meds_sglt2              -0.004347
#                                 baseline_meds_steroid            -0.004347
#                                 baseline_meds_immunosuppresant   -0.006152
#                                 Diagn_sympt_dyspnoea             -0.007873
#                                 Diagn_sympt_edema                -0.009747
#                                 Diagn_sympt_jointpain            -0.007539
#                                 Diagn_sympt_card_shock           -0.004347
#                                 Diagn_nyha                        0.009762
#                                 Diagn_modality_echo               0.006796
#                                 Diagn_modality_cct               -0.006152
#                                 Diagn_modality_stress_ecg        -0.006152
# fhxcad___0                      baseline_autoimmune_disease       0.004142
#                                 baseline_meds_oac                 0.005415
#                                 baseline_meds_statin              0.005385
#                                 baseline_meds_nitrates           -0.002974
#                                 Diagn_sympt_orthopnoea           -0.002094
#                                 Diagn_sympt_syncope               0.009008
#                                 Diagn_sympt_typ_ap               -0.007608
#                                 Diagn_sympt_arrhythmia            0.005945
#                                 Diagn_nyha                        0.009925
#                                 Diagn_setting_acute_subacute      0.008413
# htxtobacco                      baseline_meds_at1_ag             -0.000970
#                                 baseline_meds_nitrates            0.007128
#                                 Diagn_sympt_atyp_chestpain        0.002617
#                                 Diagn_modality_emb               -0.006004
# baseline_no_prior_device        baseline_meds_metformin           0.008117
#                                 Diagn_sympt_dyspnoea              0.001185
#                                 Diagn_sympt_card_arrest          -0.006175
#                                 Diagn_modality_echo               0.007186
# baseline_icd                    fhxcad___1                       -0.009340
#                                 fhxcad___2                       -0.002738
#                                 fhxcad___3                       -0.004347
#                                 baseline_pfo_asd_occlusion       -0.001366
#                                 baseline_af                      -0.002369
#                                 baseline_pah                     -0.001933
#                                 baseline_hypertensive_cm         -0.001933
#                                 basline_osas                     -0.001933
#                                 baseline_asthma                  -0.003358
#                                 baseline_copd                    -0.001933
#                                 baseline_active_cancer           -0.001366
#                                 baseline_stroke_tia              -0.002369
#                                 baseline_vascular_disease        -0.002738
#                                 baseline_depression              -0.002738
#                                 baseline_autoimmune_disease      -0.003629
#                                 baselie_prior_myocarditis        -0.002738
#                                 baseline_dcm                     -0.003629
#                                 baseline_other                   -0.003063
#                                 baseline_vt_before_cmr           -0.002738
#                                 baseline_meds_aldosteron_ag      -0.001366
#                                 baseline_meds_entresto           -0.001366
#                                 baseline_meds_ezetemibe          -0.006652
#                                 baseline_meds_metformin          -0.007767
#                                 baseline_meds_sglt2              -0.001366
#                                 baseline_meds_insulin            -0.006652
#                                 baseline_meds_other_ad           -0.001366
#                                 baseline_meds_steroid            -0.001366
#                                 baseline_meds_nitrates           -0.004768
#                                 Diagn_type_base_or_fu            -0.001366
#                                 Diagn_sympt_none                 -0.009675
#                                 Diagn_sympt_noc_dyspnoea         -0.003358
#                                 Diagn_sympt_orthopnoea           -0.003358
#                                 Diagn_sympt_exercise_intol       -0.005521
#                                 Diagn_sympt_edema                -0.003063
#                                 Diagn_sympt_palpitation          -0.006945
#                                 Diagn_sympt_syncope              -0.009784
#                                 Diagn_sympt_card_arrest          -0.007088
#                                 Diagn_sympt_jointpain            -0.002369
#                                 Diagn_modality_none              -0.002369
#                                 Diagn_modality_cct               -0.001933
#                                 Diagn_modality_stress_ecg        -0.001933
# baseline_pfo_asd_occlusion      fhxcad___1                       -0.009340
#                                 fhxcad___2                       -0.002738
#                                 fhxcad___3                       -0.004347
#                                 baseline_icd                     -0.001366
#                                 baseline_no_comorbidity          -0.007897
#                                 baseline_af                      -0.002369
#                                 baseline_pah                     -0.001933
#                                 baseline_hypertensive_cm         -0.001933
#                                 basline_osas                     -0.001933
#                                 baseline_asthma                  -0.003358
#                                 baseline_copd                    -0.001933
#                                 baseline_active_cancer           -0.001366
#                                 baseline_stroke_tia              -0.002369
#                                 baseline_vascular_disease        -0.002738
#                                 baseline_depression              -0.002738
#                                 baseline_autoimmune_disease      -0.003629
#                                 baselie_prior_myocarditis        -0.002738
#                                 baseline_dcm                     -0.003629
#                                 baseline_chf_hosp_before_cmr     -0.003629
#                                 baseline_vt_before_cmr           -0.002738
#                                 baseline_meds_oac                -0.007228
#                                 baseline_meds_aldosteron_ag      -0.001366
#                                 baseline_meds_betablocker        -0.006190
#                                 baseline_meds_at1_ag             -0.006348
#                                 baseline_meds_entresto           -0.001366
#                                 baseline_meds_ezetemibe          -0.006652
#                                 baseline_meds_metformin          -0.007767
#                                 baseline_meds_sglt2              -0.001366
#                                 baseline_meds_insulin            -0.006652
#                                 baseline_meds_other_ad           -0.001366
#                                 baseline_meds_steroid            -0.001366
#                                 baseline_meds_immunosuppresant   -0.001933
#                                 baseline_meds_nitrates           -0.004768
#                                 Diagn_type_base_or_fu            -0.001366
#                                 Diagn_sympt_none                 -0.009675
#                                 Diagn_sympt_noc_dyspnoea         -0.003358
#                                 Diagn_sympt_orthopnoea           -0.003358
#                                 Diagn_sympt_exercise_intol       -0.005521
#                                 Diagn_sympt_edema                -0.003063
#                                 Diagn_sympt_palpitation          -0.006945
#                                 Diagn_sympt_syncope              -0.009784
#                                 Diagn_sympt_card_arrest          -0.007088
#                                 Diagn_sympt_jointpain            -0.002369
#                                 Diagn_sympt_card_shock           -0.001366
#                                 Diagn_modality_none              -0.002369
#                                 Diagn_modality_cct               -0.001933
#                                 Diagn_modality_stress_ecg        -0.001933
# baseline_no_comorbidity         hxdm                             -0.003832
#                                 baseline_pfo_asd_occlusion       -0.007897
#                                 baseline_active_cancer           -0.007897
#                                 baseline_meds_oac                -0.006335
#                                 baseline_meds_aldosteron_ag      -0.007897
#                                 baseline_meds_entresto           -0.007897
#                                 baseline_meds_sglt2              -0.007897
#                                 baseline_meds_other_ad           -0.007897
#                                 baseline_meds_steroid            -0.007897
#                                 Diagn_type_base_or_fu            -0.007897
#                                 Diagn_sympt_card_arrest          -0.004875
#                                 Diagn_nyha3or4                   -0.002635
# baseline_af                     sex_0_male_1_female              -0.007994
#                                 hxhtn                             0.009126
#                                 fhxcad___3                       -0.007539
#                                 baseline_icd                     -0.002369
#                                 baseline_pfo_asd_occlusion       -0.002369
#                                 baseline_pah                     -0.003353
#                                 baseline_hypertensive_cm         -0.003353
#                                 baseline_asthma                  -0.005824
#                                 baseline_copd                    -0.003353
#                                 baseline_active_cancer           -0.002369
#                                 baseline_stroke_tia              -0.004110
#                                 baseline_vascular_disease        -0.004749
#                                 baseline_autoimmune_disease      -0.006295
#                                 baselie_prior_myocarditis        -0.004749
#                                 baseline_dcm                     -0.006295
#                                 baseline_other                   -0.005313
#                                 baseline_meds_aldosteron_ag      -0.002369
#                                 baseline_meds_ace                 0.001749
#                                 baseline_meds_entresto           -0.002369
#                                 baseline_meds_sglt2              -0.002369
#                                 baseline_meds_other_ad           -0.002369
#                                 baseline_meds_steroid            -0.002369
#                                 baseline_meds_immunosuppresant   -0.003353
#                                 baseline_meds_nitrates           -0.008270
#                                 Diagn_type_base_or_fu            -0.002369
#                                 Diagn_sympt_dyspnoea              0.000248
#                                 Diagn_sympt_noc_dyspnoea         -0.005824
#                                 Diagn_sympt_edema                -0.005313
#                                 Diagn_sympt_any_chestpain         0.005236
#                                 Diagn_sympt_jointpain            -0.004110
#                                 Diagn_sympt_card_shock           -0.002369
#                                 Diagn_nyha2or3or4                -0.004831
#                                 Diagn_modality_none              -0.004110
#                                 Diagn_modality_cct               -0.003353
#                                 Diagn_modality_stress_ecg        -0.003353
# baseline_pah                    fhxcad___2                       -0.003875
#                                 fhxcad___3                       -0.006152
#                                 baseline_icd                     -0.001933
#                                 baseline_pfo_asd_occlusion       -0.001933
#                                 baseline_af                      -0.003353
#                                 baseline_hypertensive_cm         -0.002736
#                                 basline_osas                     -0.002736
#                                 baseline_asthma                  -0.004752
#                                 baseline_copd                    -0.002736
#                                 baseline_active_cancer           -0.001933
#                                 baseline_stroke_tia              -0.003353
#                                 baseline_vascular_disease        -0.003875
#                                 baseline_depression              -0.003875
#                                 baselie_prior_myocarditis        -0.003875
#                                 baseline_dcm                     -0.005136
#                                 baseline_chf_hosp_before_cmr     -0.005136
#                                 baseline_vt_before_cmr           -0.003875
#                                 baseline_meds_aldosteron_ag      -0.001933
#                                 baseline_meds_betablocker        -0.008760
#                                 baseline_meds_at1_ag             -0.008983
#                                 baseline_meds_entresto           -0.001933
#                                 baseline_meds_ezetemibe          -0.009414
#                                 baseline_meds_sglt2              -0.001933
#                                 baseline_meds_insulin            -0.009414
#                                 baseline_meds_other_ad           -0.001933
#                                 baseline_meds_steroid            -0.001933
#                                 baseline_meds_nitrates           -0.006748
#                                 Diagn_type_base_or_fu            -0.001933
#                                 Diagn_sympt_noc_dyspnoea         -0.004752
#                                 Diagn_sympt_orthopnoea           -0.004752
#                                 Diagn_sympt_exercise_intol       -0.007814
#                                 Diagn_sympt_edema                -0.004335
#                                 Diagn_sympt_palpitation          -0.009829
#                                 Diagn_sympt_card_shock           -0.001933
#                                 Diagn_modality_none              -0.003353
#                                 Diagn_modality_cct               -0.002736
#                                 Diagn_modality_stress_ecg        -0.002736
# baseline_hypertensive_cm        global_circumf_strain            -0.009319
#                                 global_radial_strain              0.002824
#                                 fhxcad___2                       -0.003875
#                                 fhxcad___3                       -0.006152
#                                 baseline_icd                     -0.001933
#                                 baseline_pfo_asd_occlusion       -0.001933
#                                 baseline_af                      -0.003353
#                                 baseline_pah                     -0.002736
#                                 basline_osas                     -0.002736
#                                 baseline_asthma                  -0.004752
#                                 baseline_copd                    -0.002736
#                                 baseline_active_cancer           -0.001933
#                                 baseline_depression              -0.003875
#                                 baseline_autoimmune_disease      -0.005136
#                                 baselie_prior_myocarditis        -0.003875
#                                 baseline_dcm                     -0.005136
#                                 baseline_other                   -0.004335
#                                 baseline_chf_hosp_before_cmr     -0.005136
#                                 baseline_meds_aldosteron_ag      -0.001933
#                                 baseline_meds_entresto           -0.001933
#                                 baseline_meds_ezetemibe          -0.009414
#                                 baseline_meds_sglt2              -0.001933
#                                 baseline_meds_insulin            -0.009414
#                                 baseline_meds_other_ad           -0.001933
#                                 baseline_meds_steroid            -0.001933
#                                 baseline_meds_immunosuppresant   -0.002736
#                                 baseline_meds_nitrates           -0.006748
#                                 Diagn_type_base_or_fu            -0.001933
#                                 Diagn_sympt_noc_dyspnoea         -0.004752
#                                 Diagn_sympt_orthopnoea           -0.004752
#                                 Diagn_sympt_exercise_intol       -0.007814
#                                 Diagn_sympt_edema                -0.004335
#                                 Diagn_sympt_palpitation          -0.009829
#                                 Diagn_sympt_jointpain            -0.003353
#                                 Diagn_sympt_card_shock           -0.001933
#                                 Diagn_setting_acute_subacute      0.003504
#                                 Diagn_modality_none              -0.003353
#                                 Diagn_modality_cct               -0.002736
#                                 Diagn_modality_stress_ecg        -0.002736
# basline_osas                    fhxcad___3                       -0.006152
#                                 baseline_icd                     -0.001933
#                                 baseline_pfo_asd_occlusion       -0.001933
#                                 baseline_pah                     -0.002736
#                                 baseline_hypertensive_cm         -0.002736
#                                 baseline_asthma                  -0.004752
#                                 baseline_copd                    -0.002736
#                                 baseline_active_cancer           -0.001933
#                                 baseline_stroke_tia              -0.003353
#                                 baseline_vascular_disease        -0.003875
#                                 baseline_depression              -0.003875
#                                 baseline_autoimmune_disease      -0.005136
#                                 baselie_prior_myocarditis        -0.003875
#                                 baseline_other                   -0.004335
#                                 baseline_vt_before_cmr           -0.003875
#                                 baseline_meds_aldosteron_ag      -0.001933
#                                 baseline_meds_at1_ag             -0.008983
#                                 baseline_meds_ezetemibe          -0.009414
#                                 baseline_meds_sglt2              -0.001933
#                                 baseline_meds_insulin            -0.009414
#                                 baseline_meds_other_ad           -0.001933
#                                 baseline_meds_steroid            -0.001933
#                                 baseline_meds_immunosuppresant   -0.002736
#                                 baseline_meds_nitrates           -0.006748
#                                 Diagn_type_base_or_fu            -0.001933
#                                 Diagn_sympt_noc_dyspnoea         -0.004752
#                                 Diagn_sympt_edema                -0.004335
#                                 Diagn_sympt_jointpain            -0.003353
#                                 Diagn_sympt_card_shock           -0.001933
#                                 Diagn_setting_acute_subacute      0.003504
#                                 Diagn_modality_none              -0.003353
#                                 Diagn_modality_cct               -0.002736
#                                 Diagn_modality_stress_ecg        -0.002736
# baseline_asthma                 mace                              0.003502
#                                 fhxcad___2                       -0.006729
#                                 baseline_icd                     -0.003358
#                                 baseline_pfo_asd_occlusion       -0.003358
#                                 baseline_af                      -0.005824
#                                 baseline_pah                     -0.004752
#                                 baseline_hypertensive_cm         -0.004752
#                                 basline_osas                     -0.004752
#                                 baseline_copd                    -0.004752
#                                 baseline_active_cancer           -0.003358
#                                 baseline_depression              -0.006729
#                                 baseline_dcm                     -0.008920
#                                 baseline_other                   -0.007529
#                                 baseline_vt_before_cmr           -0.006729
#                                 baseline_meds_aldosteron_ag      -0.003358
#                                 baseline_meds_entresto           -0.003358
#                                 baseline_meds_sglt2              -0.003358
#                                 baseline_meds_immunosuppresant   -0.004752
#                                 Diagn_type_base_or_fu            -0.003358
#                                 Diagn_sympt_noc_dyspnoea         -0.008253
#                                 Diagn_sympt_orthopnoea           -0.008253
#                                 Diagn_sympt_edema                -0.007529
#                                 Diagn_sympt_card_shock           -0.003358
#                                 Diagn_nyha3or4                   -0.005922
#                                 Diagn_setting_acute_subacute      0.006087
#                                 Diagn_modality_cct               -0.004752
# baseline_copd                   fhxcad___3                       -0.006152
#                                 baseline_icd                     -0.001933
#                                 baseline_pfo_asd_occlusion       -0.001933
#                                 baseline_af                      -0.003353
#                                 baseline_pah                     -0.002736
#                                 baseline_hypertensive_cm         -0.002736
#                                 basline_osas                     -0.002736
#                                 baseline_asthma                  -0.004752
#                                 baseline_active_cancer           -0.001933
#                                 baseline_stroke_tia              -0.003353
#                                 baseline_depression              -0.003875
#                                 baseline_autoimmune_disease      -0.005136
#                                 baselie_prior_myocarditis        -0.003875
#                                 baseline_other                   -0.004335
#                                 baseline_vt_before_cmr           -0.003875
#                                 baseline_meds_aldosteron_ag      -0.001933
#                                 baseline_meds_at1_ag             -0.008983
#                                 baseline_meds_entresto           -0.001933
#                                 baseline_meds_ezetemibe          -0.009414
#                                 baseline_meds_sglt2              -0.001933
#                                 baseline_meds_insulin            -0.009414
#                                 baseline_meds_other_ad           -0.001933
#                                 baseline_meds_steroid            -0.001933
#                                 baseline_meds_immunosuppresant   -0.002736
#                                 baseline_meds_nitrates           -0.006748
#                                 Diagn_type_base_or_fu            -0.001933
#                                 Diagn_sympt_noc_dyspnoea         -0.004752
#                                 Diagn_sympt_orthopnoea           -0.004752
#                                 Diagn_sympt_exercise_intol       -0.007814
#                                 Diagn_sympt_edema                -0.004335
#                                 Diagn_sympt_palpitation          -0.009829
#                                 Diagn_sympt_jointpain            -0.003353
#                                 Diagn_sympt_card_shock           -0.001933
#                                 Diagn_modality_none              -0.003353
#                                 Diagn_modality_cct               -0.002736
#                                 Diagn_modality_stress_ecg        -0.002736
# baseline_active_cancer          bmi                               0.008427
#                                 fhxcad___1                       -0.009340
#                                 fhxcad___2                       -0.002738
#                                 fhxcad___3                       -0.004347
#                                 baseline_icd                     -0.001366
#                                 baseline_pfo_asd_occlusion       -0.001366
#                                 baseline_no_comorbidity          -0.007897
#                                 baseline_af                      -0.002369
#                                 baseline_pah                     -0.001933
#                                 baseline_hypertensive_cm         -0.001933
#                                 basline_osas                     -0.001933
#                                 baseline_asthma                  -0.003358
#                                 baseline_copd                    -0.001933
#                                 baseline_stroke_tia              -0.002369
#                                 baseline_vascular_disease        -0.002738
#                                 baseline_depression              -0.002738
#                                 baseline_autoimmune_disease      -0.003629
#                                 baselie_prior_myocarditis        -0.002738
#                                 baseline_dcm                     -0.003629
#                                 baseline_other                   -0.003063
#                                 baseline_chf_hosp_before_cmr     -0.003629
#                                 baseline_vt_before_cmr           -0.002738
#                                 baseline_meds_none               -0.007767
#                                 baseline_meds_oac                -0.007228
#                                 baseline_meds_aldosteron_ag      -0.001366
#                                 baseline_meds_at1_ag             -0.006348
#                                 baseline_meds_entresto           -0.001366
#                                 baseline_meds_ezetemibe          -0.006652
#                                 baseline_meds_insulin            -0.006652
#                                 baseline_meds_other_ad           -0.001366
#                                 baseline_meds_steroid            -0.001366
#                                 baseline_meds_immunosuppresant   -0.001933
#                                 baseline_meds_nitrates           -0.004768
#                                 Diagn_type_base_or_fu            -0.001366
#                                 Diagn_sympt_noc_dyspnoea         -0.003358
#                                 Diagn_sympt_orthopnoea           -0.003358
#                                 Diagn_sympt_exercise_intol       -0.005521
#                                 Diagn_sympt_edema                -0.003063
#                                 Diagn_sympt_palpitation          -0.006945
#                                 Diagn_sympt_syncope              -0.009784
#                                 Diagn_sympt_card_arrest          -0.007088
#                                 Diagn_sympt_jointpain            -0.002369
#                                 Diagn_sympt_card_shock           -0.001366
#                                 Diagn_modality_none              -0.002369
#                                 Diagn_modality_catheter          -0.008997
#                                 Diagn_modality_cct               -0.001933
#                                 Diagn_modality_stress_ecg        -0.001933
# baseline_stroke_tia             global_radial_strain              0.007872
#                                 endo_radial_strain                0.009629
#                                 sex_0_male_1_female              -0.007994
#                                 hxhtn                             0.009126
#                                 fhxcad___2                       -0.004749
#                                 baseline_icd                     -0.002369
#                                 baseline_pfo_asd_occlusion       -0.002369
#                                 baseline_af                      -0.004110
#                                 baseline_pah                     -0.003353
#                                 basline_osas                     -0.003353
#                                 baseline_copd                    -0.003353
#                                 baseline_active_cancer           -0.002369
#                                 baseline_vascular_disease        -0.004749
#                                 baseline_depression              -0.004749
#                                 baselie_prior_myocarditis        -0.004749
#                                 baseline_dcm                     -0.006295
#                                 baseline_other                   -0.005313
#                                 baseline_chf_hosp_before_cmr     -0.006295
#                                 baseline_vt_before_cmr           -0.004749
#                                 baseline_meds_aldosteron_ag      -0.002369
#                                 baseline_meds_ace                 0.001749
#                                 baseline_meds_entresto           -0.002369
#                                 baseline_meds_sglt2              -0.002369
#                                 baseline_meds_other_ad           -0.002369
#                                 baseline_meds_immunosuppresant   -0.003353
#                                 baseline_meds_nitrates           -0.008270
#                                 Diagn_sympt_dyspnoea              0.000248
#                                 Diagn_sympt_noc_dyspnoea         -0.005824
#                                 Diagn_sympt_orthopnoea           -0.005824
#                                 Diagn_sympt_edema                -0.005313
#                                 Diagn_sympt_any_chestpain         0.005236
#                                 Diagn_sympt_jointpain            -0.004110
#                                 Diagn_sympt_card_shock           -0.002369
#                                 Diagn_nyha2or3or4                -0.004831
#                                 Diagn_modality_cct               -0.003353
#                                 Diagn_modality_stress_ecg        -0.003353
# baseline_vascular_disease       baseline_icd                     -0.002738
#                                 baseline_pfo_asd_occlusion       -0.002738
#                                 baseline_af                      -0.004749
#                                 baseline_pah                     -0.003875
#                                 basline_osas                     -0.003875
#                                 baseline_active_cancer           -0.002738
#                                 baseline_stroke_tia              -0.004749
#                                 baseline_depression              -0.005487
#                                 baseline_autoimmune_disease      -0.007274
#                                 baseline_other                   -0.006139
#                                 baseline_meds_aldosteron_ag      -0.002738
#                                 baseline_meds_entresto           -0.002738
#                                 baseline_meds_statin              0.008601
#                                 baseline_meds_sglt2              -0.002738
#                                 baseline_meds_steroid            -0.002738
#                                 baseline_meds_immunosuppresant   -0.003875
#                                 baseline_meds_nitrates           -0.009556
#                                 Diagn_type_base_or_fu            -0.002738
#                                 Diagn_sympt_noc_dyspnoea         -0.006729
#                                 Diagn_sympt_orthopnoea           -0.006729
#                                 Diagn_sympt_edema                -0.006139
#                                 Diagn_sympt_any_chestpain        -0.007471
#                                 Diagn_sympt_jointpain            -0.004749
#                                 Diagn_sympt_card_shock           -0.002738
#                                 Diagn_nyha                        0.002594
#                                 Diagn_modality_stress_ecg        -0.003875
# baseline_depression             fhxcad___2                       -0.005487
#                                 fhxcad___3                       -0.008712
#                                 baseline_icd                     -0.002738
#                                 baseline_pfo_asd_occlusion       -0.002738
# ...
#                                 Diagn_modality_cct               -0.003353
#                                 Diagn_modality_stress_ecg        -0.003353
# Diagn_sympt_card_shock          fhxcad___1                       -0.009340
#                                 fhxcad___2                       -0.002738
#                                 fhxcad___3                       -0.004347
#                                 baseline_pfo_asd_occlusion       -0.001366
#                                 baseline_af                      -0.002369
#                                 baseline_pah                     -0.001933
#                                 baseline_hypertensive_cm         -0.001933
#                                 basline_osas                     -0.001933
#                                 baseline_asthma                  -0.003358
#                                 baseline_copd                    -0.001933
#                                 baseline_active_cancer           -0.001366
#                                 baseline_stroke_tia              -0.002369
#                                 baseline_vascular_disease        -0.002738
#                                 baseline_depression              -0.002738
#                                 baseline_autoimmune_disease      -0.003629
#                                 baselie_prior_myocarditis        -0.002738
#                                 baseline_dcm                     -0.003629
#                                 baseline_other                   -0.003063
#                                 baseline_vt_before_cmr           -0.002738
#                                 baseline_meds_aldosteron_ag      -0.001366
#                                 baseline_meds_entresto           -0.001366
#                                 baseline_meds_ezetemibe          -0.006652
#                                 baseline_meds_metformin          -0.007767
#                                 baseline_meds_sglt2              -0.001366
#                                 baseline_meds_insulin            -0.006652
#                                 baseline_meds_other_ad           -0.001366
#                                 baseline_meds_steroid            -0.001366
#                                 baseline_meds_nitrates           -0.004768
#                                 Diagn_type_base_or_fu            -0.001366
#                                 Diagn_sympt_none                 -0.009675
#                                 Diagn_sympt_noc_dyspnoea         -0.003358
#                                 Diagn_sympt_orthopnoea           -0.003358
#                                 Diagn_sympt_exercise_intol       -0.005521
#                                 Diagn_sympt_edema                -0.003063
#                                 Diagn_sympt_palpitation          -0.006945
#                                 Diagn_sympt_syncope              -0.009784
#                                 Diagn_sympt_card_arrest          -0.007088
#                                 Diagn_sympt_jointpain            -0.002369
#                                 Diagn_modality_none              -0.002369
#                                 Diagn_modality_cct               -0.001933
#                                 Diagn_modality_stress_ecg        -0.001933
# Diagn_nyha                      hxchol                           -0.007716
#                                 fhxcad___3                        0.009762
#                                 fhxcad___0                        0.009925
#                                 baseline_vascular_disease         0.002594
#                                 baseline_other                   -0.009028
#                                 baseline_meds_ezetemibe          -0.003084
#                                 Diagn_sympt_jointpain            -0.002882
# Diagn_nyha3or4                  baseline_no_comorbidity          -0.002635
#                                 baseline_asthma                  -0.005922
# Diagn_nyha2or3or4               baseline_af                      -0.004831
#                                 baseline_stroke_tia              -0.004831
# Diagn_setting_acute_subacute    endo_circumf_strain              -0.007317
#                                 global_radial_strain              0.007386
#                                 endo_radial_strain               -0.007311
#                                 hxdm                             -0.008902
#                                 fhxcad___0                        0.008413
#                                 baseline_hypertensive_cm          0.003504
#                                 basline_osas                      0.003504
#                                 baseline_asthma                   0.006087
#                                 baseline_depression               0.004963
#                                 baseline_autoimmune_disease      -0.007480
#                                 baseline_meds_oac                -0.008675
#                                 baseline_meds_at1_ag              0.003310
#                                 Diagn_sympt_orthopnoea            0.006087
#                                 Diagn_sympt_syncope               0.006681
#                                 Diagn_modality_cct                0.003504
# Diagn_modality_none             global_longit_strain             -0.002356
#                                 endo_longit_strain               -0.001493
#                                 epi_longit_strain                 0.001082
#                                 sex_0_male_1_female              -0.007994
#                                 bmi                              -0.006438
#                                 hxhtn                             0.009126
#                                 fhxcad___2                       -0.004749
#                                 baseline_icd                     -0.002369
#                                 baseline_pfo_asd_occlusion       -0.002369
#                                 baseline_af                      -0.004110
#                                 baseline_pah                     -0.003353
#                                 baseline_hypertensive_cm         -0.003353
#                                 basline_osas                     -0.003353
#                                 baseline_copd                    -0.003353
#                                 baseline_active_cancer           -0.002369
#                                 baseline_depression              -0.004749
#                                 baseline_dcm                     -0.006295
#                                 baseline_other                   -0.005313
#                                 baseline_chf_hosp_before_cmr     -0.006295
#                                 baseline_vt_before_cmr           -0.004749
#                                 baseline_meds_aldosteron_ag      -0.002369
#                                 baseline_meds_entresto           -0.002369
#                                 baseline_meds_sglt2              -0.002369
#                                 baseline_meds_immunosuppresant   -0.003353
#                                 baseline_meds_nitrates           -0.008270
#                                 Diagn_type_base_or_fu            -0.002369
#                                 Diagn_sympt_noc_dyspnoea         -0.005824
#                                 Diagn_sympt_orthopnoea           -0.005824
#                                 Diagn_sympt_edema                -0.005313
#                                 Diagn_sympt_jointpain            -0.004110
#                                 Diagn_sympt_card_shock           -0.002369
#                                 Diagn_modality_cct               -0.003353
#                                 Diagn_modality_stress_ecg        -0.003353
# Diagn_modality_echo             hxdm                             -0.004347
#                                 hxchol                            0.006229
#                                 fhxcad___3                        0.006796
#                                 baseline_no_prior_device          0.007186
#                                 baseline_dcm                     -0.007337
#                                 baseline_meds_betablocker         0.009679
#                                 baseline_meds_calcium_ag          0.002824
#                                 baseline_meds_ace                -0.000974
#                                 baseline_meds_metformin          -0.006720
#                                 Diagn_sympt_exercise_intol       -0.002914
# Diagn_modality_catheter         global_longit_strain              0.002439
#                                 epi_longit_strain                 0.008540
#                                 age                               0.001980
#                                 hxdm                             -0.001517
#                                 baseline_active_cancer           -0.008997
#                                 baseline_meds_sglt2              -0.008997
#                                 baseline_meds_other_ad           -0.008997
#                                 baseline_meds_steroid            -0.008997
#                                 Diagn_modality_emb               -0.002958
# Diagn_modality_cct              global_longit_strain              0.004839
#                                 epi_longit_strain                 0.003469
#                                 global_circumf_strain             0.004305
#                                 endo_circumf_strain               0.002956
#                                 epi_circumf_strain               -0.007628
#                                 epi_radial_strain                 0.002533
#                                 age                              -0.003668
#                                 fhxcad___2                       -0.003875
#                                 fhxcad___3                       -0.006152
#                                 baseline_icd                     -0.001933
#                                 baseline_pfo_asd_occlusion       -0.001933
#                                 baseline_af                      -0.003353
#                                 baseline_pah                     -0.002736
#                                 baseline_hypertensive_cm         -0.002736
#                                 basline_osas                     -0.002736
#                                 baseline_asthma                  -0.004752
#                                 baseline_copd                    -0.002736
#                                 baseline_active_cancer           -0.001933
#                                 baseline_stroke_tia              -0.003353
#                                 baseline_depression              -0.003875
#                                 baseline_autoimmune_disease      -0.005136
#                                 baselie_prior_myocarditis        -0.003875
#                                 baseline_dcm                     -0.005136
#                                 baseline_other                   -0.004335
#                                 baseline_chf_hosp_before_cmr     -0.005136
#                                 baseline_vt_before_cmr           -0.003875
#                                 baseline_meds_aldosteron_ag      -0.001933
#                                 baseline_meds_betablocker        -0.008760
#                                 baseline_meds_at1_ag             -0.008983
#                                 baseline_meds_entresto           -0.001933
#                                 baseline_meds_ezetemibe          -0.009414
#                                 baseline_meds_sglt2              -0.001933
#                                 baseline_meds_insulin            -0.009414
#                                 baseline_meds_other_ad           -0.001933
#                                 baseline_meds_steroid            -0.001933
#                                 baseline_meds_immunosuppresant   -0.002736
#                                 baseline_meds_nitrates           -0.006748
#                                 Diagn_type_base_or_fu            -0.001933
#                                 Diagn_sympt_noc_dyspnoea         -0.004752
#                                 Diagn_sympt_orthopnoea           -0.004752
#                                 Diagn_sympt_exercise_intol       -0.007814
#                                 Diagn_sympt_edema                -0.004335
#                                 Diagn_sympt_palpitation          -0.009829
#                                 Diagn_sympt_jointpain            -0.003353
#                                 Diagn_sympt_card_shock           -0.001933
#                                 Diagn_setting_acute_subacute      0.003504
#                                 Diagn_modality_none              -0.003353
#                                 Diagn_modality_stress_ecg        -0.002736
# Diagn_modality_emb              sex_0_male_1_female              -0.000832
#                                 htxtobacco                       -0.006004
#                                 baseline_meds_none               -0.009400
#                                 baseline_meds_ezetemibe           0.007154
#                                 baseline_meds_nitrates            0.003368
#                                 Diagn_sympt_exercise_intol       -0.007816
#                                 Diagn_sympt_typ_ap               -0.008640
#                                 Diagn_modality_catheter          -0.002958
# Diagn_modality_stress_ecg       fhxcad___2                       -0.003875
#                                 fhxcad___3                       -0.006152
#                                 baseline_icd                     -0.001933
#                                 baseline_pfo_asd_occlusion       -0.001933
#                                 baseline_af                      -0.003353
#                                 baseline_pah                     -0.002736
#                                 baseline_hypertensive_cm         -0.002736
#                                 basline_osas                     -0.002736
#                                 baseline_copd                    -0.002736
#                                 baseline_active_cancer           -0.001933
#                                 baseline_stroke_tia              -0.003353
#                                 baseline_vascular_disease        -0.003875
#                                 baseline_depression              -0.003875
#                                 baseline_autoimmune_disease      -0.005136
#                                 baselie_prior_myocarditis        -0.003875
#                                 baseline_dcm                     -0.005136
#                                 baseline_other                   -0.004335
#                                 baseline_chf_hosp_before_cmr     -0.005136
#                                 baseline_vt_before_cmr           -0.003875
#                                 baseline_meds_aldosteron_ag      -0.001933
#                                 baseline_meds_at1_ag             -0.008983
#                                 baseline_meds_entresto           -0.001933
#                                 baseline_meds_ezetemibe          -0.009414
#                                 baseline_meds_sglt2              -0.001933
#                                 baseline_meds_insulin            -0.009414
#                                 baseline_meds_other_ad           -0.001933
#                                 baseline_meds_steroid            -0.001933
#                                 baseline_meds_immunosuppresant   -0.002736
#                                 baseline_meds_nitrates           -0.006748
#                                 Diagn_type_base_or_fu            -0.001933
#                                 Diagn_sympt_noc_dyspnoea         -0.004752
#                                 Diagn_sympt_edema                -0.004335
#                                 Diagn_sympt_jointpain            -0.003353
#                                 Diagn_sympt_card_shock           -0.001933
#                                 Diagn_modality_none              -0.003353
#                                 Diagn_modality_cct               -0.002736
# dtype: float64

# %%
plt.imshow(matrix, cmap='hot', interpolation='nearest')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.imshow(matrix, cmap='hot', interpolation='nearest')
#       2 plt.show()
#
# File ~/miniconda3/envs/data_parser/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/data_parser/lib/python3.9/site-packages/matplotlib/pyplot.py:2631, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2625 @_copy_docstring_and_deprecators(Axes.imshow)
#    2626 def imshow(
#    2627         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    2628         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    2629         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2630         resample=None, url=None, data=None, **kwargs):
# -> 2631     __ret = gca().imshow(
#    2632         X, cmap=cmap, norm=norm, aspect=aspect,
#    2633         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2634         vmax=vmax, origin=origin, extent=extent,
#    2635         interpolation_stage=interpolation_stage,
#    2636         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2637         url=url, **({"data": data} if data is not None else {}),
#    2638         **kwargs)
#    2639     sci(__ret)
#    2640     return __ret
#
# File ~/miniconda3/envs/data_parser/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/data_parser/lib/python3.9/site-packages/matplotlib/__init__.py:1433, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1430 @functools.wraps(func)
#    1431 def inner(ax, *args, data=None, **kwargs):
#    1432     if data is None:
# -> 1433         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1435     bound = new_sig.bind(ax, *args, **kwargs)
#    1436     auto_label = (bound.arguments.get(label_namer)
#    1437                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/data_parser/lib/python3.9/site-packages/matplotlib/axes/_axes.py:5610, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5602 self.set_aspect(aspect)
#    5603 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5604                       interpolation=interpolation, origin=origin,
#    5605                       extent=extent, filternorm=filternorm,
#    5606                       filterrad=filterrad, resample=resample,
#    5607                       interpolation_stage=interpolation_stage,
#    5608                       **kwargs)
# -> 5610 im.set_data(X)
#    5611 im.set_alpha(alpha)
#    5612 if im.get_clip_path() is None:
#    5613     # image does not already have clipping set, clip to axes patch
#
# File ~/miniconda3/envs/data_parser/lib/python3.9/site-packages/matplotlib/image.py:710, in _ImageBase.set_data(self, A)
#     706     self._A = self._A[:, :, 0]
#     708 if not (self._A.ndim == 2
#     709         or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 710     raise TypeError("Invalid shape {} for image data"
#     711                     .format(self._A.shape))
#     713 if self._A.ndim == 3:
#     714     # If the input data has values outside the valid range (after
#     715     # normalisation), we issue a warning and then clip X to the bounds
#     716     # - otherwise casting wraps extreme values, hiding outliers and
#     717     # making reliable interpretation impossible.
#     718     high = 255 if np.issubdtype(self._A.dtype, np.integer) else 1
#
# TypeError: Invalid shape (7680,) for image data
